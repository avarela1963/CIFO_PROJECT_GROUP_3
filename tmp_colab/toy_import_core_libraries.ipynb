# %% [markdown]
# <a href="https://colab.research.google.com/github/avarela1963/CIFO_PROJECT_GROUP_3/blob/main/tmp_colab/toy_import_core_libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
